# %% [markdown]
# <a href="https://colab.research.google.com/github/Joshi-Ketaki/MLPlayground/blob/main/Stateless_Shuffling_History_MLMastery.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# STUDY STATELESSNESS AND SHUFFLING
# THIS IS ON ONE TO ONE CHAR MAPPING, I.E. PREDICT NEXT CHAR GIVEN CURRENT CHAR
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras.utils import to_categorical

# fix random seed for reproducibility
tf.random.set_seed(7)

# define the raw dataset
alphabet = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"
# create mapping of characters to integers (0-25) and the reverse
char_to_int = dict((c, i) for i, c in enumerate(alphabet))
int_to_char = dict((i, c) for i, c in enumerate(alphabet))

# prepare the dataset of input to output pairs encoded as integers
seq_length = 1
dataX = []
dataY = []
for i in range(0, len(alphabet) - seq_length, 1):
	seq_in = alphabet[i:i + seq_length]
	seq_out = alphabet[i + seq_length]
	dataX.append([char_to_int[char] for char in seq_in])
	dataY.append(char_to_int[seq_out])
	print(seq_in, '->', seq_out)

# reshape X to be [samples, time steps, features]
X = np.reshape(dataX, (len(dataX), seq_length, 1))

# normalize
# print("before normalization X", X)
# this is 1 to 26
X = X / float(len(alphabet))
# print("after normalization X", X)
# this is convert 1 to 26 as values between 0 and 1.

# one hot encode the output variable
y = to_categorical(dataY)
# print(y)
# array of 0 and 1 where 1 is at the index of the number encoded above

#############################################################
# PREDICT NEXT CHARACHTER BASED ON CURRENT CHARACHTER
# THIS IS  BATCH SIZE 1 OR 1 INPUT SAMPLE AT A TIME
# create and fit the model
# layers stacked on each other
model = Sequential()
model.add(LSTM(32, input_shape=(X.shape[1], X.shape[2])))
# this is pytorch linear layer
model.add(Dense(y.shape[1], activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
# 1. DATA SHUFFLING:
# Keras shuffles training data after each epoch
# This will disturb the sequential pattern learning
# with default setting i.e. shuffle=true, accuracy = 80% (batch_size=1)
# model.fit(X, y, epochs=500, batch_size= 1, verbose=2)
# Putting shuffle = True, accuracy increases to 88% (this is with batch size=1)
# model.fit(X, y, epochs=500, batch_size= 1, verbose=2, shuffle=False)

# 2. BATCH SIZE, STATEFULLNESS, STATELESSNESS
# Keras default resets state after each batch.
# So, if batch_size = 1 and seq_length > batch_size, state will be reset
# after each batch.
# one way of maintaining state using default settings is batch_size >= length_of_data
# This required more epochs to achive 100% accuracy

# But note that this hacky statefullness makes context available during training, but
# not during testing
# This is 'statefull', shuffle=False, this achieved accuracy = 100%,
model.fit(X, y, epochs=5000, batch_size=len(dataX), verbose=2, shuffle=False)

# This is 'statefull', shuffle=True, this also achieved accuracy = 100%
# model.fit(X, y, epochs=5000, batch_size=len(dataX), verbose=2, shuffle=True)

#Summary:
# Not shuffling data increases accuracy in stateless models.
# If mosel maintains states across batches, then irrespective of shuffling or not shuffling data
# accuracy is maintained
# Therefore, effect of statefull/less >> shuffling
# summarize performance of the model
scores = model.evaluate(X, y, verbose=0)
print("Model Accuracy: %.2f%%" % (scores[1]*100))

# demonstrate some model predictions
for pattern in dataX:
	x = np.reshape(pattern, (1, len(pattern), 1))
	x = x / float(len(alphabet))
	prediction = model.predict(x, verbose=0)
	index = np.argmax(prediction)
	result = int_to_char[index]
	seq_in = [int_to_char[value] for value in pattern]
	print(seq_in, "->", result)


# demonstrate predicting random patterns
print("Test a Random Pattern:")
for i in range(0,20):
 pattern_index = np.random.randint(len(dataX))
 pattern = dataX[pattern_index]
 x = np.reshape(pattern, (1, len(pattern), 1))
 x = x / float(len(alphabet))
 prediction = model.predict(x, verbose=0)
 index = np.argmax(prediction)
 result = int_to_char[index]
 seq_in = [int_to_char[value] for value in pattern]
 print(seq_in, "->", result)
#############################################################

# %%
# STUDY HISTORY- AS FEATURES OR TIMESTEPS
# Naive LSTM to learn three-char window to one-char mapping (
# (DEFAULT: BATCH_SIZE=1 AND SHUFFLE=FALSE)
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras.utils import to_categorical
# fix random seed for reproducibility
tf.random.set_seed(7)
# define the raw dataset
alphabet = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"
# create mapping of characters to integers (0-25) and the reverse
char_to_int = dict((c, i) for i, c in enumerate(alphabet))
int_to_char = dict((i, c) for i, c in enumerate(alphabet))
# prepare the dataset of input to output pairs encoded as integers
seq_length = 3
dataX = []
dataY = []
for i in range(0, len(alphabet) - seq_length, 1):
	seq_in = alphabet[i:i + seq_length]
	seq_out = alphabet[i + seq_length]
	dataX.append([char_to_int[char] for char in seq_in])
	dataY.append(char_to_int[seq_out])
	print(seq_in, '->', seq_out)

# 1. CREATES A THREE CHARACHTER FEATURE WINDOW
# reshape X to be [samples, time steps, features]
# example : [[ 3  4  5]]
X = np.reshape(dataX, (len(dataX), 1, seq_length))
#print("CREATES A THREE CHARACHTER FEATURE WINDOW", X)
# accuracy for this is 86.96%
# why: in this setup, we give more context to the network in one TS.
# but network wants more sequences also to learn better.
# this is not given by this setup.

# 2. CREATES A THREE TIMESTEP WINDOW
# reshape X to be [samples, time steps, features]
# example:
# [[ 3]
#  [ 4]
#  [ 5]]
#X = np.reshape(dataX, (len(dataX), seq_length, 1))
#print ("2. CREATES A THREE TIMESTEP WINDOW", X)
# accuracy for this is 100%
# why : here we are giving more sequences to the network (each seq is diff, see the example)
# and more context for learning (three TS for each sample)
# accuracy better.

# normalize
X = X / float(len(alphabet))
# one hot encode the output variable
y = to_categorical(dataY)
# create and fit the model
model = Sequential()
model.add(LSTM(32, input_shape=(X.shape[1], X.shape[2])))
model.add(Dense(y.shape[1], activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
# DEFAULT HAS ACCURACY 86.96%
# SHUFFLE=FALSE ALSO HAS ACCURACY 86.96%
model.fit(X, y, epochs=500, batch_size=1, verbose=2, shuffle=False)
# summarize performance of the model
scores = model.evaluate(X, y, verbose=0)
print("Model Accuracy: %.2f%%" % (scores[1]*100))
# demonstrate some model predictions
for pattern in dataX:
  # This is for three timesteps window
  #x = np.reshape(pattern, (1, len(pattern), 1))
	# This is for three features window
  x = np.reshape(pattern, (1, 1, len(pattern)))
  x = x / float(len(alphabet))
  prediction = model.predict(x, verbose=0)
  index = np.argmax(prediction)
  result = int_to_char[index]
  seq_in = [int_to_char[value] for value in pattern]
  print(seq_in, "->", result)
# Out:
# ABC -> D
# BCD -> E
# CDE -> F
# DEF -> G
# EFG -> H
# FGH -> I
# GHI -> J
# HIJ -> K
# IJK -> L
# JKL -> M
# KLM -> N
# LMN -> O
# MNO -> P
# NOP -> Q
# OPQ -> R
# PQR -> S
# QRS -> T
# RST -> U
# STU -> V
# TUV -> W
# UVW -> X
# VWX -> Y
# WXY -> Z
# Epoch 1/500
# 23/23 - 3s - loss: 3.2688 - accuracy: 0.0435 - 3s/epoch - 111ms/step
# Epoch 2/500
# 23/23 - 0s - loss: 3.2566 - accuracy: 0.0870 - 47ms/epoch - 2ms/step
# Epoch 3/500
# 23/23 - 0s - loss: 3.2502 - accuracy: 0.0870 - 48ms/epoch - 2ms/step
# Epoch 4/500
# 23/23 - 0s - loss: 3.2440 - accuracy: 0.0870 - 49ms/epoch - 2ms/step
# Epoch 5/500
# 23/23 - 0s - loss: 3.2377 - accuracy: 0.0870 - 44ms/epoch - 2ms/step
# Epoch 6/500
# 23/23 - 0s - loss: 3.2313 - accuracy: 0.0870 - 49ms/epoch - 2ms/step
# Epoch 7/500
# 23/23 - 0s - loss: 3.2246 - accuracy: 0.0435 - 44ms/epoch - 2ms/step
# Epoch 8/500
# 23/23 - 0s - loss: 3.2175 - accuracy: 0.0000e+00 - 45ms/epoch - 2ms/step
# Epoch 9/500
# 23/23 - 0s - loss: 3.2100 - accuracy: 0.0000e+00 - 46ms/epoch - 2ms/step
# Epoch 10/500
# 23/23 - 0s - loss: 3.2019 - accuracy: 0.0000e+00 - 46ms/epoch - 2ms/step
# Epoch 11/500
# 23/23 - 0s - loss: 3.1933 - accuracy: 0.0000e+00 - 47ms/epoch - 2ms/step
# Epoch 12/500
# 23/23 - 0s - loss: 3.1843 - accuracy: 0.0000e+00 - 47ms/epoch - 2ms/step
# Epoch 13/500
# 23/23 - 0s - loss: 3.1748 - accuracy: 0.0435 - 45ms/epoch - 2ms/step
# Epoch 14/500
# 23/23 - 0s - loss: 3.1649 - accuracy: 0.0435 - 49ms/epoch - 2ms/step
# Epoch 15/500
# 23/23 - 0s - loss: 3.1547 - accuracy: 0.0435 - 43ms/epoch - 2ms/step
# Epoch 16/500
# 23/23 - 0s - loss: 3.1444 - accuracy: 0.0435 - 52ms/epoch - 2ms/step
# Epoch 17/500
# 23/23 - 0s - loss: 3.1341 - accuracy: 0.0000e+00 - 44ms/epoch - 2ms/step
# Epoch 18/500
# 23/23 - 0s - loss: 3.1239 - accuracy: 0.0435 - 42ms/epoch - 2ms/step
# Epoch 19/500
# 23/23 - 0s - loss: 3.1139 - accuracy: 0.0435 - 43ms/epoch - 2ms/step
# Epoch 20/500
# 23/23 - 0s - loss: 3.1042 - accuracy: 0.0435 - 43ms/epoch - 2ms/step
# Epoch 21/500
# 23/23 - 0s - loss: 3.0948 - accuracy: 0.0435 - 54ms/epoch - 2ms/step
# Epoch 22/500
# 23/23 - 0s - loss: 3.0858 - accuracy: 0.0435 - 42ms/epoch - 2ms/step
# Epoch 23/500
# 23/23 - 0s - loss: 3.0771 - accuracy: 0.0435 - 45ms/epoch - 2ms/step
# Epoch 24/500
# 23/23 - 0s - loss: 3.0688 - accuracy: 0.0435 - 50ms/epoch - 2ms/step
# Epoch 25/500
# 23/23 - 0s - loss: 3.0608 - accuracy: 0.0435 - 42ms/epoch - 2ms/step
# Epoch 26/500
# 23/23 - 0s - loss: 3.0531 - accuracy: 0.0435 - 52ms/epoch - 2ms/step
# Epoch 27/500
# 23/23 - 0s - loss: 3.0456 - accuracy: 0.0435 - 45ms/epoch - 2ms/step
# Epoch 28/500
# 23/23 - 0s - loss: 3.0383 - accuracy: 0.0435 - 46ms/epoch - 2ms/step
# Epoch 29/500
# 23/23 - 0s - loss: 3.0312 - accuracy: 0.0435 - 44ms/epoch - 2ms/step
# Epoch 30/500
# 23/23 - 0s - loss: 3.0242 - accuracy: 0.0435 - 45ms/epoch - 2ms/step
# Epoch 31/500
# 23/23 - 0s - loss: 3.0172 - accuracy: 0.0435 - 45ms/epoch - 2ms/step
# Epoch 32/500
# 23/23 - 0s - loss: 3.0103 - accuracy: 0.0435 - 49ms/epoch - 2ms/step
# Epoch 33/500
# 23/23 - 0s - loss: 3.0034 - accuracy: 0.0435 - 44ms/epoch - 2ms/step
# Epoch 34/500
# 23/23 - 0s - loss: 2.9964 - accuracy: 0.0435 - 44ms/epoch - 2ms/step
# Epoch 35/500
# 23/23 - 0s - loss: 2.9894 - accuracy: 0.0870 - 45ms/epoch - 2ms/step
# Epoch 36/500
# 23/23 - 0s - loss: 2.9822 - accuracy: 0.0870 - 42ms/epoch - 2ms/step
# Epoch 37/500
# 23/23 - 0s - loss: 2.9750 - accuracy: 0.0870 - 52ms/epoch - 2ms/step
# Epoch 38/500
# 23/23 - 0s - loss: 2.9676 - accuracy: 0.0870 - 42ms/epoch - 2ms/step
# Epoch 39/500
# 23/23 - 0s - loss: 2.9600 - accuracy: 0.1304 - 44ms/epoch - 2ms/step
# Epoch 40/500
# 23/23 - 0s - loss: 2.9523 - accuracy: 0.1304 - 43ms/epoch - 2ms/step
# Epoch 41/500
# 23/23 - 0s - loss: 2.9444 - accuracy: 0.1304 - 47ms/epoch - 2ms/step
# Epoch 42/500
# 23/23 - 0s - loss: 2.9363 - accuracy: 0.1304 - 47ms/epoch - 2ms/step
# Epoch 43/500
# 23/23 - 0s - loss: 2.9280 - accuracy: 0.1304 - 44ms/epoch - 2ms/step
# Epoch 44/500
# 23/23 - 0s - loss: 2.9195 - accuracy: 0.1304 - 53ms/epoch - 2ms/step
# Epoch 45/500
# 23/23 - 0s - loss: 2.9108 - accuracy: 0.1304 - 45ms/epoch - 2ms/step
# Epoch 46/500
# 23/23 - 0s - loss: 2.9019 - accuracy: 0.1304 - 42ms/epoch - 2ms/step
# Epoch 47/500
# 23/23 - 0s - loss: 2.8928 - accuracy: 0.1304 - 53ms/epoch - 2ms/step
# Epoch 48/500
# 23/23 - 0s - loss: 2.8835 - accuracy: 0.0870 - 45ms/epoch - 2ms/step
# Epoch 49/500
# 23/23 - 0s - loss: 2.8739 - accuracy: 0.0870 - 41ms/epoch - 2ms/step
# Epoch 50/500
# 23/23 - 0s - loss: 2.8642 - accuracy: 0.1304 - 55ms/epoch - 2ms/step
# Epoch 51/500
# 23/23 - 0s - loss: 2.8544 - accuracy: 0.1304 - 51ms/epoch - 2ms/step
# Epoch 52/500
# 23/23 - 0s - loss: 2.8443 - accuracy: 0.1304 - 43ms/epoch - 2ms/step
# Epoch 53/500
# 23/23 - 0s - loss: 2.8342 - accuracy: 0.0870 - 44ms/epoch - 2ms/step
# Epoch 54/500
# 23/23 - 0s - loss: 2.8239 - accuracy: 0.0870 - 43ms/epoch - 2ms/step
# Epoch 55/500
# 23/23 - 0s - loss: 2.8135 - accuracy: 0.0870 - 44ms/epoch - 2ms/step
# Epoch 56/500
# 23/23 - 0s - loss: 2.8030 - accuracy: 0.0870 - 54ms/epoch - 2ms/step
# Epoch 57/500
# 23/23 - 0s - loss: 2.7925 - accuracy: 0.0870 - 45ms/epoch - 2ms/step
# Epoch 58/500
# 23/23 - 0s - loss: 2.7819 - accuracy: 0.0870 - 42ms/epoch - 2ms/step
# Epoch 59/500
# 23/23 - 0s - loss: 2.7713 - accuracy: 0.0870 - 43ms/epoch - 2ms/step
# Epoch 60/500
# 23/23 - 0s - loss: 2.7608 - accuracy: 0.0870 - 42ms/epoch - 2ms/step
# Epoch 61/500
# 23/23 - 0s - loss: 2.7502 - accuracy: 0.0870 - 48ms/epoch - 2ms/step
# Epoch 62/500
# 23/23 - 0s - loss: 2.7398 - accuracy: 0.0870 - 42ms/epoch - 2ms/step
# Epoch 63/500
# 23/23 - 0s - loss: 2.7294 - accuracy: 0.0870 - 43ms/epoch - 2ms/step
# Epoch 64/500
# 23/23 - 0s - loss: 2.7191 - accuracy: 0.0870 - 54ms/epoch - 2ms/step
# Epoch 65/500
# 23/23 - 0s - loss: 2.7090 - accuracy: 0.0870 - 45ms/epoch - 2ms/step
# Epoch 66/500
# 23/23 - 0s - loss: 2.6990 - accuracy: 0.0870 - 43ms/epoch - 2ms/step
# Epoch 67/500
# 23/23 - 0s - loss: 2.6891 - accuracy: 0.0870 - 43ms/epoch - 2ms/step
# Epoch 68/500
# 23/23 - 0s - loss: 2.6794 - accuracy: 0.0870 - 44ms/epoch - 2ms/step
# Epoch 69/500
# 23/23 - 0s - loss: 2.6699 - accuracy: 0.0870 - 44ms/epoch - 2ms/step
# Epoch 70/500
# 23/23 - 0s - loss: 2.6605 - accuracy: 0.0870 - 47ms/epoch - 2ms/step
# Epoch 71/500
# 23/23 - 0s - loss: 2.6514 - accuracy: 0.0870 - 54ms/epoch - 2ms/step
# Epoch 72/500
# 23/23 - 0s - loss: 2.6424 - accuracy: 0.0870 - 44ms/epoch - 2ms/step
# Epoch 73/500
# 23/23 - 0s - loss: 2.6336 - accuracy: 0.0870 - 45ms/epoch - 2ms/step
# Epoch 74/500
# 23/23 - 0s - loss: 2.6250 - accuracy: 0.0870 - 44ms/epoch - 2ms/step
# Epoch 75/500
# 23/23 - 0s - loss: 2.6166 - accuracy: 0.0870 - 45ms/epoch - 2ms/step
# Epoch 76/500
# 23/23 - 0s - loss: 2.6084 - accuracy: 0.0870 - 43ms/epoch - 2ms/step
# Epoch 77/500
# 23/23 - 0s - loss: 2.6004 - accuracy: 0.0870 - 42ms/epoch - 2ms/step
# Epoch 78/500
# 23/23 - 0s - loss: 2.5925 - accuracy: 0.0870 - 43ms/epoch - 2ms/step
# Epoch 79/500
# 23/23 - 0s - loss: 2.5848 - accuracy: 0.0870 - 44ms/epoch - 2ms/step
# Epoch 80/500
# 23/23 - 0s - loss: 2.5773 - accuracy: 0.0870 - 55ms/epoch - 2ms/step
# Epoch 81/500
# 23/23 - 0s - loss: 2.5699 - accuracy: 0.0870 - 44ms/epoch - 2ms/step
# Epoch 82/500
# 23/23 - 0s - loss: 2.5627 - accuracy: 0.0870 - 48ms/epoch - 2ms/step
# Epoch 83/500
# 23/23 - 0s - loss: 2.5557 - accuracy: 0.0870 - 46ms/epoch - 2ms/step
# Epoch 84/500
# 23/23 - 0s - loss: 2.5488 - accuracy: 0.0870 - 43ms/epoch - 2ms/step
# Epoch 85/500
# 23/23 - 0s - loss: 2.5420 - accuracy: 0.0870 - 56ms/epoch - 2ms/step
# Epoch 86/500
# 23/23 - 0s - loss: 2.5354 - accuracy: 0.0870 - 48ms/epoch - 2ms/step
# Epoch 87/500
# 23/23 - 0s - loss: 2.5289 - accuracy: 0.0870 - 43ms/epoch - 2ms/step
# Epoch 88/500
# 23/23 - 0s - loss: 2.5225 - accuracy: 0.0870 - 47ms/epoch - 2ms/step
# Epoch 89/500
# 23/23 - 0s - loss: 2.5162 - accuracy: 0.0870 - 53ms/epoch - 2ms/step
# Epoch 90/500
# 23/23 - 0s - loss: 2.5100 - accuracy: 0.0870 - 53ms/epoch - 2ms/step
# Epoch 91/500
# 23/23 - 0s - loss: 2.5039 - accuracy: 0.0870 - 43ms/epoch - 2ms/step
# Epoch 92/500
# 23/23 - 0s - loss: 2.4979 - accuracy: 0.0870 - 42ms/epoch - 2ms/step
# Epoch 93/500
# 23/23 - 0s - loss: 2.4920 - accuracy: 0.0870 - 44ms/epoch - 2ms/step
# Epoch 94/500
# 23/23 - 0s - loss: 2.4862 - accuracy: 0.0870 - 50ms/epoch - 2ms/step
# Epoch 95/500
# 23/23 - 0s - loss: 2.4805 - accuracy: 0.0870 - 45ms/epoch - 2ms/step
# Epoch 96/500
# 23/23 - 0s - loss: 2.4748 - accuracy: 0.0870 - 44ms/epoch - 2ms/step
# Epoch 97/500
# 23/23 - 0s - loss: 2.4692 - accuracy: 0.0870 - 43ms/epoch - 2ms/step
# Epoch 98/500
# 23/23 - 0s - loss: 2.4637 - accuracy: 0.0870 - 43ms/epoch - 2ms/step
# Epoch 99/500
# 23/23 - 0s - loss: 2.4583 - accuracy: 0.0870 - 51ms/epoch - 2ms/step
# Epoch 100/500
# 23/23 - 0s - loss: 2.4529 - accuracy: 0.1304 - 42ms/epoch - 2ms/step
# Epoch 101/500
# 23/23 - 0s - loss: 2.4475 - accuracy: 0.1304 - 44ms/epoch - 2ms/step
# Epoch 102/500
# 23/23 - 0s - loss: 2.4423 - accuracy: 0.1739 - 45ms/epoch - 2ms/step
# Epoch 103/500
# 23/23 - 0s - loss: 2.4370 - accuracy: 0.1739 - 45ms/epoch - 2ms/step
# Epoch 104/500
# 23/23 - 0s - loss: 2.4319 - accuracy: 0.1739 - 48ms/epoch - 2ms/step
# Epoch 105/500
# 23/23 - 0s - loss: 2.4267 - accuracy: 0.1739 - 56ms/epoch - 2ms/step
# Epoch 106/500
# 23/23 - 0s - loss: 2.4216 - accuracy: 0.1739 - 43ms/epoch - 2ms/step
# Epoch 107/500
# 23/23 - 0s - loss: 2.4166 - accuracy: 0.1739 - 43ms/epoch - 2ms/step
# Epoch 108/500
# 23/23 - 0s - loss: 2.4116 - accuracy: 0.2174 - 51ms/epoch - 2ms/step
# Epoch 109/500
# 23/23 - 0s - loss: 2.4067 - accuracy: 0.2174 - 49ms/epoch - 2ms/step
# Epoch 110/500
# 23/23 - 0s - loss: 2.4018 - accuracy: 0.2174 - 45ms/epoch - 2ms/step
# Epoch 111/500
# 23/23 - 0s - loss: 2.3969 - accuracy: 0.2174 - 43ms/epoch - 2ms/step
# Epoch 112/500
# 23/23 - 0s - loss: 2.3921 - accuracy: 0.2174 - 42ms/epoch - 2ms/step
# Epoch 113/500
# 23/23 - 0s - loss: 2.3873 - accuracy: 0.2174 - 50ms/epoch - 2ms/step
# Epoch 114/500
# 23/23 - 0s - loss: 2.3825 - accuracy: 0.2174 - 43ms/epoch - 2ms/step
# Epoch 115/500
# 23/23 - 0s - loss: 2.3778 - accuracy: 0.2174 - 42ms/epoch - 2ms/step
# Epoch 116/500
# 23/23 - 0s - loss: 2.3732 - accuracy: 0.2174 - 42ms/epoch - 2ms/step
# Epoch 117/500
# 23/23 - 0s - loss: 2.3685 - accuracy: 0.2174 - 44ms/epoch - 2ms/step
# Epoch 118/500
# 23/23 - 0s - loss: 2.3639 - accuracy: 0.2174 - 53ms/epoch - 2ms/step
# Epoch 119/500
# 23/23 - 0s - loss: 2.3594 - accuracy: 0.2174 - 42ms/epoch - 2ms/step
# Epoch 120/500
# 23/23 - 0s - loss: 2.3548 - accuracy: 0.2174 - 45ms/epoch - 2ms/step
# Epoch 121/500
# 23/23 - 0s - loss: 2.3503 - accuracy: 0.2174 - 44ms/epoch - 2ms/step
# Epoch 122/500
# 23/23 - 0s - loss: 2.3459 - accuracy: 0.2174 - 44ms/epoch - 2ms/step
# Epoch 123/500
# 23/23 - 0s - loss: 2.3415 - accuracy: 0.2174 - 50ms/epoch - 2ms/step
# Epoch 124/500
# 23/23 - 0s - loss: 2.3371 - accuracy: 0.2174 - 50ms/epoch - 2ms/step
# Epoch 125/500
# 23/23 - 0s - loss: 2.3327 - accuracy: 0.2174 - 55ms/epoch - 2ms/step
# Epoch 126/500
# 23/23 - 0s - loss: 2.3284 - accuracy: 0.2609 - 43ms/epoch - 2ms/step
# Epoch 127/500
# 23/23 - 0s - loss: 2.3241 - accuracy: 0.2609 - 42ms/epoch - 2ms/step
# Epoch 128/500
# 23/23 - 0s - loss: 2.3198 - accuracy: 0.2609 - 52ms/epoch - 2ms/step
# Epoch 129/500
# 23/23 - 0s - loss: 2.3156 - accuracy: 0.2609 - 43ms/epoch - 2ms/step
# Epoch 130/500
# 23/23 - 0s - loss: 2.3114 - accuracy: 0.2609 - 44ms/epoch - 2ms/step
# Epoch 131/500
# 23/23 - 0s - loss: 2.3073 - accuracy: 0.2609 - 43ms/epoch - 2ms/step
# Epoch 132/500
# 23/23 - 0s - loss: 2.3031 - accuracy: 0.2609 - 43ms/epoch - 2ms/step
# Epoch 133/500
# 23/23 - 0s - loss: 2.2990 - accuracy: 0.2609 - 46ms/epoch - 2ms/step
# Epoch 134/500
# 23/23 - 0s - loss: 2.2950 - accuracy: 0.2609 - 42ms/epoch - 2ms/step
# Epoch 135/500
# 23/23 - 0s - loss: 2.2909 - accuracy: 0.2609 - 44ms/epoch - 2ms/step
# Epoch 136/500
# 23/23 - 0s - loss: 2.2869 - accuracy: 0.2609 - 43ms/epoch - 2ms/step
# Epoch 137/500
# 23/23 - 0s - loss: 2.2830 - accuracy: 0.2609 - 44ms/epoch - 2ms/step
# Epoch 138/500
# 23/23 - 0s - loss: 2.2790 - accuracy: 0.2609 - 46ms/epoch - 2ms/step
# Epoch 139/500
# 23/23 - 0s - loss: 2.2751 - accuracy: 0.2174 - 44ms/epoch - 2ms/step
# Epoch 140/500
# 23/23 - 0s - loss: 2.2712 - accuracy: 0.2174 - 44ms/epoch - 2ms/step
# Epoch 141/500
# 23/23 - 0s - loss: 2.2674 - accuracy: 0.2174 - 46ms/epoch - 2ms/step
# Epoch 142/500
# 23/23 - 0s - loss: 2.2635 - accuracy: 0.2174 - 48ms/epoch - 2ms/step
# Epoch 143/500
# 23/23 - 0s - loss: 2.2597 - accuracy: 0.2174 - 44ms/epoch - 2ms/step
# Epoch 144/500
# 23/23 - 0s - loss: 2.2560 - accuracy: 0.2174 - 45ms/epoch - 2ms/step
# Epoch 145/500
# 23/23 - 0s - loss: 2.2522 - accuracy: 0.2174 - 45ms/epoch - 2ms/step
# Epoch 146/500
# 23/23 - 0s - loss: 2.2485 - accuracy: 0.2174 - 56ms/epoch - 2ms/step
# Epoch 147/500
# 23/23 - 0s - loss: 2.2448 - accuracy: 0.2174 - 49ms/epoch - 2ms/step
# Epoch 148/500
# 23/23 - 0s - loss: 2.2411 - accuracy: 0.2174 - 45ms/epoch - 2ms/step
# Epoch 149/500
# 23/23 - 0s - loss: 2.2375 - accuracy: 0.2174 - 47ms/epoch - 2ms/step
# Epoch 150/500
# 23/23 - 0s - loss: 2.2339 - accuracy: 0.2174 - 47ms/epoch - 2ms/step
# Epoch 151/500
# 23/23 - 0s - loss: 2.2303 - accuracy: 0.2174 - 48ms/epoch - 2ms/step
# Epoch 152/500
# 23/23 - 0s - loss: 2.2267 - accuracy: 0.2174 - 48ms/epoch - 2ms/step
# Epoch 153/500
# 23/23 - 0s - loss: 2.2232 - accuracy: 0.2174 - 46ms/epoch - 2ms/step
# Epoch 154/500
# 23/23 - 0s - loss: 2.2196 - accuracy: 0.2174 - 44ms/epoch - 2ms/step
# Epoch 155/500
# 23/23 - 0s - loss: 2.2161 - accuracy: 0.2174 - 44ms/epoch - 2ms/step
# Epoch 156/500
# 23/23 - 0s - loss: 2.2127 - accuracy: 0.2174 - 54ms/epoch - 2ms/step
# Epoch 157/500
# 23/23 - 0s - loss: 2.2092 - accuracy: 0.2174 - 44ms/epoch - 2ms/step
# Epoch 158/500
# 23/23 - 0s - loss: 2.2058 - accuracy: 0.2174 - 44ms/epoch - 2ms/step
# Epoch 159/500
# 23/23 - 0s - loss: 2.2024 - accuracy: 0.2174 - 45ms/epoch - 2ms/step
# Epoch 160/500
# 23/23 - 0s - loss: 2.1990 - accuracy: 0.2174 - 43ms/epoch - 2ms/step
# Epoch 161/500
# 23/23 - 0s - loss: 2.1956 - accuracy: 0.2174 - 42ms/epoch - 2ms/step
# Epoch 162/500
# 23/23 - 0s - loss: 2.1923 - accuracy: 0.2174 - 47ms/epoch - 2ms/step
# Epoch 163/500
# 23/23 - 0s - loss: 2.1890 - accuracy: 0.2609 - 43ms/epoch - 2ms/step
# Epoch 164/500
# 23/23 - 0s - loss: 2.1857 - accuracy: 0.2609 - 44ms/epoch - 2ms/step
# Epoch 165/500
# 23/23 - 0s - loss: 2.1824 - accuracy: 0.2609 - 44ms/epoch - 2ms/step
# Epoch 166/500
# 23/23 - 0s - loss: 2.1792 - accuracy: 0.2609 - 50ms/epoch - 2ms/step
# Epoch 167/500
# 23/23 - 0s - loss: 2.1759 - accuracy: 0.3043 - 53ms/epoch - 2ms/step
# Epoch 168/500
# 23/23 - 0s - loss: 2.1727 - accuracy: 0.3043 - 43ms/epoch - 2ms/step
# Epoch 169/500
# 23/23 - 0s - loss: 2.1695 - accuracy: 0.3043 - 42ms/epoch - 2ms/step
# Epoch 170/500
# 23/23 - 0s - loss: 2.1663 - accuracy: 0.3043 - 51ms/epoch - 2ms/step
# Epoch 171/500
# 23/23 - 0s - loss: 2.1632 - accuracy: 0.3043 - 45ms/epoch - 2ms/step
# Epoch 172/500
# 23/23 - 0s - loss: 2.1600 - accuracy: 0.3043 - 60ms/epoch - 3ms/step
# Epoch 173/500
# 23/23 - 0s - loss: 2.1569 - accuracy: 0.3043 - 66ms/epoch - 3ms/step
# Epoch 174/500
# 23/23 - 0s - loss: 2.1538 - accuracy: 0.3043 - 60ms/epoch - 3ms/step
# Epoch 175/500
# 23/23 - 0s - loss: 2.1508 - accuracy: 0.3043 - 63ms/epoch - 3ms/step
# Epoch 176/500
# 23/23 - 0s - loss: 2.1477 - accuracy: 0.3043 - 61ms/epoch - 3ms/step
# Epoch 177/500
# 23/23 - 0s - loss: 2.1446 - accuracy: 0.3043 - 59ms/epoch - 3ms/step
# Epoch 178/500
# 23/23 - 0s - loss: 2.1416 - accuracy: 0.3043 - 62ms/epoch - 3ms/step
# Epoch 179/500
# 23/23 - 0s - loss: 2.1386 - accuracy: 0.3043 - 65ms/epoch - 3ms/step
# Epoch 180/500
# 23/23 - 0s - loss: 2.1356 - accuracy: 0.3043 - 63ms/epoch - 3ms/step
# Epoch 181/500
# 23/23 - 0s - loss: 2.1326 - accuracy: 0.3043 - 69ms/epoch - 3ms/step
# Epoch 182/500
# 23/23 - 0s - loss: 2.1297 - accuracy: 0.3478 - 62ms/epoch - 3ms/step
# Epoch 183/500
# 23/23 - 0s - loss: 2.1267 - accuracy: 0.3478 - 67ms/epoch - 3ms/step
# Epoch 184/500
# 23/23 - 0s - loss: 2.1238 - accuracy: 0.3478 - 63ms/epoch - 3ms/step
# Epoch 185/500
# 23/23 - 0s - loss: 2.1209 - accuracy: 0.3478 - 65ms/epoch - 3ms/step
# Epoch 186/500
# 23/23 - 0s - loss: 2.1180 - accuracy: 0.3478 - 59ms/epoch - 3ms/step
# Epoch 187/500
# 23/23 - 0s - loss: 2.1151 - accuracy: 0.3478 - 60ms/epoch - 3ms/step
# Epoch 188/500
# 23/23 - 0s - loss: 2.1123 - accuracy: 0.3913 - 59ms/epoch - 3ms/step
# Epoch 189/500
# 23/23 - 0s - loss: 2.1094 - accuracy: 0.3913 - 60ms/epoch - 3ms/step
# Epoch 190/500
# 23/23 - 0s - loss: 2.1066 - accuracy: 0.3913 - 59ms/epoch - 3ms/step
# Epoch 191/500
# 23/23 - 0s - loss: 2.1038 - accuracy: 0.3913 - 60ms/epoch - 3ms/step
# Epoch 192/500
# 23/23 - 0s - loss: 2.1010 - accuracy: 0.3913 - 62ms/epoch - 3ms/step
# Epoch 193/500
# 23/23 - 0s - loss: 2.0982 - accuracy: 0.3913 - 62ms/epoch - 3ms/step
# Epoch 194/500
# 23/23 - 0s - loss: 2.0955 - accuracy: 0.3913 - 68ms/epoch - 3ms/step
# Epoch 195/500
# 23/23 - 0s - loss: 2.0927 - accuracy: 0.3913 - 60ms/epoch - 3ms/step
# Epoch 196/500
# 23/23 - 0s - loss: 2.0900 - accuracy: 0.3913 - 61ms/epoch - 3ms/step
# Epoch 197/500
# 23/23 - 0s - loss: 2.0872 - accuracy: 0.3913 - 60ms/epoch - 3ms/step
# Epoch 198/500
# 23/23 - 0s - loss: 2.0845 - accuracy: 0.3913 - 61ms/epoch - 3ms/step
# Epoch 199/500
# 23/23 - 0s - loss: 2.0818 - accuracy: 0.3913 - 63ms/epoch - 3ms/step
# Epoch 200/500
# 23/23 - 0s - loss: 2.0792 - accuracy: 0.3913 - 64ms/epoch - 3ms/step
# Epoch 201/500
# 23/23 - 0s - loss: 2.0765 - accuracy: 0.3913 - 62ms/epoch - 3ms/step
# Epoch 202/500
# 23/23 - 0s - loss: 2.0738 - accuracy: 0.3913 - 60ms/epoch - 3ms/step
# Epoch 203/500
# 23/23 - 0s - loss: 2.0712 - accuracy: 0.3913 - 61ms/epoch - 3ms/step
# Epoch 204/500
# 23/23 - 0s - loss: 2.0686 - accuracy: 0.3913 - 60ms/epoch - 3ms/step
# Epoch 205/500
# 23/23 - 0s - loss: 2.0660 - accuracy: 0.3913 - 60ms/epoch - 3ms/step
# Epoch 206/500
# 23/23 - 0s - loss: 2.0634 - accuracy: 0.3913 - 62ms/epoch - 3ms/step
# Epoch 207/500
# 23/23 - 0s - loss: 2.0608 - accuracy: 0.3913 - 74ms/epoch - 3ms/step
# Epoch 208/500
# 23/23 - 0s - loss: 2.0582 - accuracy: 0.3913 - 60ms/epoch - 3ms/step
# Epoch 209/500
# 23/23 - 0s - loss: 2.0556 - accuracy: 0.3913 - 60ms/epoch - 3ms/step
# Epoch 210/500
# 23/23 - 0s - loss: 2.0531 - accuracy: 0.4348 - 62ms/epoch - 3ms/step
# Epoch 211/500
# 23/23 - 0s - loss: 2.0506 - accuracy: 0.4348 - 59ms/epoch - 3ms/step
# Epoch 212/500
# 23/23 - 0s - loss: 2.0480 - accuracy: 0.4348 - 63ms/epoch - 3ms/step
# Epoch 213/500
# 23/23 - 0s - loss: 2.0455 - accuracy: 0.4348 - 64ms/epoch - 3ms/step
# Epoch 214/500
# 23/23 - 0s - loss: 2.0430 - accuracy: 0.4348 - 64ms/epoch - 3ms/step
# Epoch 215/500
# 23/23 - 0s - loss: 2.0405 - accuracy: 0.4348 - 70ms/epoch - 3ms/step
# Epoch 216/500
# 23/23 - 0s - loss: 2.0381 - accuracy: 0.4348 - 43ms/epoch - 2ms/step
# Epoch 217/500
# 23/23 - 0s - loss: 2.0356 - accuracy: 0.4348 - 42ms/epoch - 2ms/step
# Epoch 218/500
# 23/23 - 0s - loss: 2.0332 - accuracy: 0.4348 - 47ms/epoch - 2ms/step
# Epoch 219/500
# 23/23 - 0s - loss: 2.0307 - accuracy: 0.4348 - 44ms/epoch - 2ms/step
# Epoch 220/500
# 23/23 - 0s - loss: 2.0283 - accuracy: 0.4348 - 44ms/epoch - 2ms/step
# Epoch 221/500
# 23/23 - 0s - loss: 2.0259 - accuracy: 0.4348 - 46ms/epoch - 2ms/step
# Epoch 222/500
# 23/23 - 0s - loss: 2.0235 - accuracy: 0.4348 - 43ms/epoch - 2ms/step
# Epoch 223/500
# 23/23 - 0s - loss: 2.0211 - accuracy: 0.4348 - 57ms/epoch - 2ms/step
# Epoch 224/500
# 23/23 - 0s - loss: 2.0187 - accuracy: 0.4348 - 42ms/epoch - 2ms/step
# Epoch 225/500
# 23/23 - 0s - loss: 2.0163 - accuracy: 0.4348 - 43ms/epoch - 2ms/step
# Epoch 226/500
# 23/23 - 0s - loss: 2.0140 - accuracy: 0.4348 - 43ms/epoch - 2ms/step
# Epoch 227/500
# 23/23 - 0s - loss: 2.0116 - accuracy: 0.4348 - 42ms/epoch - 2ms/step
# Epoch 228/500
# 23/23 - 0s - loss: 2.0093 - accuracy: 0.4348 - 51ms/epoch - 2ms/step
# Epoch 229/500
# 23/23 - 0s - loss: 2.0069 - accuracy: 0.4348 - 44ms/epoch - 2ms/step
# Epoch 230/500
# 23/23 - 0s - loss: 2.0046 - accuracy: 0.4348 - 43ms/epoch - 2ms/step
# Epoch 231/500
# 23/23 - 0s - loss: 2.0023 - accuracy: 0.4783 - 43ms/epoch - 2ms/step
# Epoch 232/500
# 23/23 - 0s - loss: 2.0000 - accuracy: 0.4783 - 44ms/epoch - 2ms/step
# Epoch 233/500
# 23/23 - 0s - loss: 1.9977 - accuracy: 0.5217 - 44ms/epoch - 2ms/step
# Epoch 234/500
# 23/23 - 0s - loss: 1.9955 - accuracy: 0.5217 - 55ms/epoch - 2ms/step
# Epoch 235/500
# 23/23 - 0s - loss: 1.9932 - accuracy: 0.5217 - 48ms/epoch - 2ms/step
# Epoch 236/500
# 23/23 - 0s - loss: 1.9910 - accuracy: 0.5217 - 49ms/epoch - 2ms/step
# Epoch 237/500
# 23/23 - 0s - loss: 1.9887 - accuracy: 0.5217 - 42ms/epoch - 2ms/step
# Epoch 238/500
# 23/23 - 0s - loss: 1.9865 - accuracy: 0.5217 - 46ms/epoch - 2ms/step
# Epoch 239/500
# 23/23 - 0s - loss: 1.9843 - accuracy: 0.5217 - 48ms/epoch - 2ms/step
# Epoch 240/500
# 23/23 - 0s - loss: 1.9820 - accuracy: 0.5652 - 46ms/epoch - 2ms/step
# Epoch 241/500
# 23/23 - 0s - loss: 1.9798 - accuracy: 0.5652 - 45ms/epoch - 2ms/step
# Epoch 242/500
# 23/23 - 0s - loss: 1.9776 - accuracy: 0.5652 - 44ms/epoch - 2ms/step
# Epoch 243/500
# 23/23 - 0s - loss: 1.9755 - accuracy: 0.5652 - 45ms/epoch - 2ms/step
# Epoch 244/500
# 23/23 - 0s - loss: 1.9733 - accuracy: 0.5652 - 51ms/epoch - 2ms/step
# Epoch 245/500
# 23/23 - 0s - loss: 1.9711 - accuracy: 0.5652 - 44ms/epoch - 2ms/step
# Epoch 246/500
# 23/23 - 0s - loss: 1.9690 - accuracy: 0.5652 - 44ms/epoch - 2ms/step
# Epoch 247/500
# 23/23 - 0s - loss: 1.9668 - accuracy: 0.5652 - 43ms/epoch - 2ms/step
# Epoch 248/500
# 23/23 - 0s - loss: 1.9647 - accuracy: 0.5652 - 48ms/epoch - 2ms/step
# Epoch 249/500
# 23/23 - 0s - loss: 1.9625 - accuracy: 0.5652 - 45ms/epoch - 2ms/step
# Epoch 250/500
# 23/23 - 0s - loss: 1.9604 - accuracy: 0.5652 - 45ms/epoch - 2ms/step
# Epoch 251/500
# 23/23 - 0s - loss: 1.9583 - accuracy: 0.5652 - 43ms/epoch - 2ms/step
# Epoch 252/500
# 23/23 - 0s - loss: 1.9562 - accuracy: 0.5652 - 44ms/epoch - 2ms/step
# Epoch 253/500
# 23/23 - 0s - loss: 1.9541 - accuracy: 0.5652 - 42ms/epoch - 2ms/step
# Epoch 254/500
# 23/23 - 0s - loss: 1.9520 - accuracy: 0.5652 - 52ms/epoch - 2ms/step
# Epoch 255/500
# 23/23 - 0s - loss: 1.9499 - accuracy: 0.5652 - 45ms/epoch - 2ms/step
# Epoch 256/500
# 23/23 - 0s - loss: 1.9479 - accuracy: 0.5652 - 51ms/epoch - 2ms/step
# Epoch 257/500
# 23/23 - 0s - loss: 1.9458 - accuracy: 0.5652 - 44ms/epoch - 2ms/step
# Epoch 258/500
# 23/23 - 0s - loss: 1.9438 - accuracy: 0.5652 - 43ms/epoch - 2ms/step
# Epoch 259/500
# 23/23 - 0s - loss: 1.9417 - accuracy: 0.5652 - 50ms/epoch - 2ms/step
# Epoch 260/500
# 23/23 - 0s - loss: 1.9397 - accuracy: 0.5652 - 43ms/epoch - 2ms/step
# Epoch 261/500
# 23/23 - 0s - loss: 1.9377 - accuracy: 0.5652 - 45ms/epoch - 2ms/step
# Epoch 262/500
# 23/23 - 0s - loss: 1.9357 - accuracy: 0.5652 - 43ms/epoch - 2ms/step
# Epoch 263/500
# 23/23 - 0s - loss: 1.9336 - accuracy: 0.5652 - 49ms/epoch - 2ms/step
# Epoch 264/500
# 23/23 - 0s - loss: 1.9316 - accuracy: 0.5652 - 45ms/epoch - 2ms/step
# Epoch 265/500
# 23/23 - 0s - loss: 1.9297 - accuracy: 0.5652 - 45ms/epoch - 2ms/step
# Epoch 266/500
# 23/23 - 0s - loss: 1.9277 - accuracy: 0.5652 - 46ms/epoch - 2ms/step
# Epoch 267/500
# 23/23 - 0s - loss: 1.9257 - accuracy: 0.5652 - 49ms/epoch - 2ms/step
# Epoch 268/500
# 23/23 - 0s - loss: 1.9237 - accuracy: 0.5652 - 52ms/epoch - 2ms/step
# Epoch 269/500
# 23/23 - 0s - loss: 1.9218 - accuracy: 0.5652 - 44ms/epoch - 2ms/step
# Epoch 270/500
# 23/23 - 0s - loss: 1.9198 - accuracy: 0.5652 - 46ms/epoch - 2ms/step
# Epoch 271/500
# 23/23 - 0s - loss: 1.9179 - accuracy: 0.6087 - 44ms/epoch - 2ms/step
# Epoch 272/500
# 23/23 - 0s - loss: 1.9159 - accuracy: 0.6087 - 43ms/epoch - 2ms/step
# Epoch 273/500
# 23/23 - 0s - loss: 1.9140 - accuracy: 0.6087 - 48ms/epoch - 2ms/step
# Epoch 274/500
# 23/23 - 0s - loss: 1.9121 - accuracy: 0.6087 - 45ms/epoch - 2ms/step
# Epoch 275/500
# 23/23 - 0s - loss: 1.9102 - accuracy: 0.6087 - 46ms/epoch - 2ms/step
# Epoch 276/500
# 23/23 - 0s - loss: 1.9083 - accuracy: 0.6087 - 50ms/epoch - 2ms/step
# Epoch 277/500
# 23/23 - 0s - loss: 1.9064 - accuracy: 0.6087 - 44ms/epoch - 2ms/step
# Epoch 278/500
# 23/23 - 0s - loss: 1.9045 - accuracy: 0.6087 - 52ms/epoch - 2ms/step
# Epoch 279/500
# 23/23 - 0s - loss: 1.9026 - accuracy: 0.6087 - 44ms/epoch - 2ms/step
# Epoch 280/500
# 23/23 - 0s - loss: 1.9007 - accuracy: 0.6087 - 48ms/epoch - 2ms/step
# Epoch 281/500
# 23/23 - 0s - loss: 1.8989 - accuracy: 0.6087 - 45ms/epoch - 2ms/step
# Epoch 282/500
# 23/23 - 0s - loss: 1.8970 - accuracy: 0.6522 - 52ms/epoch - 2ms/step
# Epoch 283/500
# 23/23 - 0s - loss: 1.8951 - accuracy: 0.6522 - 42ms/epoch - 2ms/step
# Epoch 284/500
# 23/23 - 0s - loss: 1.8933 - accuracy: 0.6522 - 43ms/epoch - 2ms/step
# Epoch 285/500
# 23/23 - 0s - loss: 1.8915 - accuracy: 0.6522 - 43ms/epoch - 2ms/step
# Epoch 286/500
# 23/23 - 0s - loss: 1.8896 - accuracy: 0.6522 - 51ms/epoch - 2ms/step
# Epoch 287/500
# 23/23 - 0s - loss: 1.8878 - accuracy: 0.6522 - 56ms/epoch - 2ms/step
# Epoch 288/500
# 23/23 - 0s - loss: 1.8860 - accuracy: 0.6522 - 47ms/epoch - 2ms/step
# Epoch 289/500
# 23/23 - 0s - loss: 1.8842 - accuracy: 0.6522 - 48ms/epoch - 2ms/step
# Epoch 290/500
# 23/23 - 0s - loss: 1.8824 - accuracy: 0.6522 - 45ms/epoch - 2ms/step
# Epoch 291/500
# 23/23 - 0s - loss: 1.8806 - accuracy: 0.6957 - 47ms/epoch - 2ms/step
# Epoch 292/500
# 23/23 - 0s - loss: 1.8788 - accuracy: 0.6957 - 48ms/epoch - 2ms/step
# Epoch 293/500
# 23/23 - 0s - loss: 1.8770 - accuracy: 0.6957 - 52ms/epoch - 2ms/step
# Epoch 294/500
# 23/23 - 0s - loss: 1.8752 - accuracy: 0.6957 - 46ms/epoch - 2ms/step
# Epoch 295/500
# 23/23 - 0s - loss: 1.8735 - accuracy: 0.6957 - 45ms/epoch - 2ms/step
# Epoch 296/500
# 23/23 - 0s - loss: 1.8717 - accuracy: 0.7391 - 62ms/epoch - 3ms/step
# Epoch 297/500
# 23/23 - 0s - loss: 1.8699 - accuracy: 0.7391 - 44ms/epoch - 2ms/step
# Epoch 298/500
# 23/23 - 0s - loss: 1.8682 - accuracy: 0.7391 - 44ms/epoch - 2ms/step
# Epoch 299/500
# 23/23 - 0s - loss: 1.8664 - accuracy: 0.7391 - 44ms/epoch - 2ms/step
# Epoch 300/500
# 23/23 - 0s - loss: 1.8647 - accuracy: 0.7391 - 44ms/epoch - 2ms/step
# Epoch 301/500
# 23/23 - 0s - loss: 1.8630 - accuracy: 0.7391 - 45ms/epoch - 2ms/step
# Epoch 302/500
# 23/23 - 0s - loss: 1.8613 - accuracy: 0.7391 - 53ms/epoch - 2ms/step
# Epoch 303/500
# 23/23 - 0s - loss: 1.8595 - accuracy: 0.7391 - 47ms/epoch - 2ms/step
# Epoch 304/500
# 23/23 - 0s - loss: 1.8578 - accuracy: 0.7391 - 46ms/epoch - 2ms/step
# Epoch 305/500
# 23/23 - 0s - loss: 1.8561 - accuracy: 0.7391 - 43ms/epoch - 2ms/step
# Epoch 306/500
# 23/23 - 0s - loss: 1.8544 - accuracy: 0.7391 - 56ms/epoch - 2ms/step
# Epoch 307/500
# 23/23 - 0s - loss: 1.8527 - accuracy: 0.7391 - 45ms/epoch - 2ms/step
# Epoch 308/500
# 23/23 - 0s - loss: 1.8511 - accuracy: 0.7391 - 43ms/epoch - 2ms/step
# Epoch 309/500
# 23/23 - 0s - loss: 1.8494 - accuracy: 0.7391 - 45ms/epoch - 2ms/step
# Epoch 310/500
# 23/23 - 0s - loss: 1.8477 - accuracy: 0.7391 - 44ms/epoch - 2ms/step
# Epoch 311/500
# 23/23 - 0s - loss: 1.8460 - accuracy: 0.7391 - 55ms/epoch - 2ms/step
# Epoch 312/500
# 23/23 - 0s - loss: 1.8444 - accuracy: 0.7391 - 44ms/epoch - 2ms/step
# Epoch 313/500
# 23/23 - 0s - loss: 1.8427 - accuracy: 0.7391 - 46ms/epoch - 2ms/step
# Epoch 314/500
# 23/23 - 0s - loss: 1.8411 - accuracy: 0.7391 - 48ms/epoch - 2ms/step
# Epoch 315/500
# 23/23 - 0s - loss: 1.8394 - accuracy: 0.7391 - 58ms/epoch - 3ms/step
# Epoch 316/500
# 23/23 - 0s - loss: 1.8378 - accuracy: 0.7391 - 49ms/epoch - 2ms/step
# Epoch 317/500
# 23/23 - 0s - loss: 1.8362 - accuracy: 0.7391 - 45ms/epoch - 2ms/step
# Epoch 318/500
# 23/23 - 0s - loss: 1.8345 - accuracy: 0.7391 - 45ms/epoch - 2ms/step
# Epoch 319/500
# 23/23 - 0s - loss: 1.8329 - accuracy: 0.7391 - 44ms/epoch - 2ms/step
# Epoch 320/500
# 23/23 - 0s - loss: 1.8313 - accuracy: 0.7391 - 52ms/epoch - 2ms/step
# Epoch 321/500
# 23/23 - 0s - loss: 1.8297 - accuracy: 0.7391 - 42ms/epoch - 2ms/step
# Epoch 322/500
# 23/23 - 0s - loss: 1.8281 - accuracy: 0.7391 - 43ms/epoch - 2ms/step
# Epoch 323/500
# 23/23 - 0s - loss: 1.8265 - accuracy: 0.7391 - 44ms/epoch - 2ms/step
# Epoch 324/500
# 23/23 - 0s - loss: 1.8249 - accuracy: 0.7391 - 43ms/epoch - 2ms/step
# Epoch 325/500
# 23/23 - 0s - loss: 1.8233 - accuracy: 0.7391 - 50ms/epoch - 2ms/step
# Epoch 326/500
# 23/23 - 0s - loss: 1.8217 - accuracy: 0.7391 - 49ms/epoch - 2ms/step
# Epoch 327/500
# 23/23 - 0s - loss: 1.8202 - accuracy: 0.7391 - 46ms/epoch - 2ms/step
# Epoch 328/500
# 23/23 - 0s - loss: 1.8186 - accuracy: 0.7391 - 48ms/epoch - 2ms/step
# Epoch 329/500
# 23/23 - 0s - loss: 1.8170 - accuracy: 0.7391 - 55ms/epoch - 2ms/step
# Epoch 330/500
# 23/23 - 0s - loss: 1.8155 - accuracy: 0.7391 - 48ms/epoch - 2ms/step
# Epoch 331/500
# 23/23 - 0s - loss: 1.8139 - accuracy: 0.7391 - 46ms/epoch - 2ms/step
# Epoch 332/500
# 23/23 - 0s - loss: 1.8124 - accuracy: 0.7391 - 43ms/epoch - 2ms/step
# Epoch 333/500
# 23/23 - 0s - loss: 1.8108 - accuracy: 0.7391 - 48ms/epoch - 2ms/step
# Epoch 334/500
# 23/23 - 0s - loss: 1.8093 - accuracy: 0.7391 - 53ms/epoch - 2ms/step
# Epoch 335/500
# 23/23 - 0s - loss: 1.8078 - accuracy: 0.7391 - 45ms/epoch - 2ms/step
# Epoch 336/500
# 23/23 - 0s - loss: 1.8062 - accuracy: 0.7391 - 54ms/epoch - 2ms/step
# Epoch 337/500
# 23/23 - 0s - loss: 1.8047 - accuracy: 0.7391 - 51ms/epoch - 2ms/step
# Epoch 338/500
# 23/23 - 0s - loss: 1.8032 - accuracy: 0.7391 - 51ms/epoch - 2ms/step
# Epoch 339/500
# 23/23 - 0s - loss: 1.8017 - accuracy: 0.7391 - 43ms/epoch - 2ms/step
# Epoch 340/500
# 23/23 - 0s - loss: 1.8002 - accuracy: 0.7391 - 46ms/epoch - 2ms/step
# Epoch 341/500
# 23/23 - 0s - loss: 1.7987 - accuracy: 0.7391 - 43ms/epoch - 2ms/step
# Epoch 342/500
# 23/23 - 0s - loss: 1.7972 - accuracy: 0.7391 - 52ms/epoch - 2ms/step
# Epoch 343/500
# 23/23 - 0s - loss: 1.7957 - accuracy: 0.7391 - 44ms/epoch - 2ms/step
# Epoch 344/500
# 23/23 - 0s - loss: 1.7942 - accuracy: 0.7391 - 44ms/epoch - 2ms/step
# Epoch 345/500
# 23/23 - 0s - loss: 1.7928 - accuracy: 0.7391 - 46ms/epoch - 2ms/step
# Epoch 346/500
# 23/23 - 0s - loss: 1.7913 - accuracy: 0.7826 - 49ms/epoch - 2ms/step
# Epoch 347/500
# 23/23 - 0s - loss: 1.7898 - accuracy: 0.7826 - 55ms/epoch - 2ms/step
# Epoch 348/500
# 23/23 - 0s - loss: 1.7884 - accuracy: 0.7826 - 44ms/epoch - 2ms/step
# Epoch 349/500
# 23/23 - 0s - loss: 1.7869 - accuracy: 0.7826 - 43ms/epoch - 2ms/step
# Epoch 350/500
# 23/23 - 0s - loss: 1.7854 - accuracy: 0.7826 - 42ms/epoch - 2ms/step
# Epoch 351/500
# 23/23 - 0s - loss: 1.7840 - accuracy: 0.7826 - 44ms/epoch - 2ms/step
# Epoch 352/500
# 23/23 - 0s - loss: 1.7825 - accuracy: 0.7826 - 55ms/epoch - 2ms/step
# Epoch 353/500
# 23/23 - 0s - loss: 1.7811 - accuracy: 0.7826 - 46ms/epoch - 2ms/step
# Epoch 354/500
# 23/23 - 0s - loss: 1.7797 - accuracy: 0.7826 - 44ms/epoch - 2ms/step
# Epoch 355/500
# 23/23 - 0s - loss: 1.7782 - accuracy: 0.7826 - 45ms/epoch - 2ms/step
# Epoch 356/500
# 23/23 - 0s - loss: 1.7768 - accuracy: 0.7826 - 52ms/epoch - 2ms/step
# Epoch 357/500
# 23/23 - 0s - loss: 1.7754 - accuracy: 0.7826 - 57ms/epoch - 2ms/step
# Epoch 358/500
# 23/23 - 0s - loss: 1.7740 - accuracy: 0.7826 - 46ms/epoch - 2ms/step
# Epoch 359/500
# 23/23 - 0s - loss: 1.7726 - accuracy: 0.7826 - 44ms/epoch - 2ms/step
# Epoch 360/500
# 23/23 - 0s - loss: 1.7712 - accuracy: 0.7826 - 44ms/epoch - 2ms/step
# Epoch 361/500
# 23/23 - 0s - loss: 1.7698 - accuracy: 0.7826 - 60ms/epoch - 3ms/step
# Epoch 362/500
# 23/23 - 0s - loss: 1.7684 - accuracy: 0.7826 - 45ms/epoch - 2ms/step
# Epoch 363/500
# 23/23 - 0s - loss: 1.7670 - accuracy: 0.8261 - 45ms/epoch - 2ms/step
# Epoch 364/500
# 23/23 - 0s - loss: 1.7656 - accuracy: 0.8261 - 43ms/epoch - 2ms/step
# Epoch 365/500
# 23/23 - 0s - loss: 1.7642 - accuracy: 0.8261 - 48ms/epoch - 2ms/step
# Epoch 366/500
# 23/23 - 0s - loss: 1.7628 - accuracy: 0.8261 - 43ms/epoch - 2ms/step
# Epoch 367/500
# 23/23 - 0s - loss: 1.7615 - accuracy: 0.8261 - 47ms/epoch - 2ms/step
# Epoch 368/500
# 23/23 - 0s - loss: 1.7601 - accuracy: 0.8261 - 48ms/epoch - 2ms/step
# Epoch 369/500
# 23/23 - 0s - loss: 1.7587 - accuracy: 0.8261 - 46ms/epoch - 2ms/step
# Epoch 370/500
# 23/23 - 0s - loss: 1.7574 - accuracy: 0.8261 - 51ms/epoch - 2ms/step
# Epoch 371/500
# 23/23 - 0s - loss: 1.7560 - accuracy: 0.8261 - 46ms/epoch - 2ms/step
# Epoch 372/500
# 23/23 - 0s - loss: 1.7547 - accuracy: 0.8261 - 45ms/epoch - 2ms/step
# Epoch 373/500
# 23/23 - 0s - loss: 1.7533 - accuracy: 0.8261 - 43ms/epoch - 2ms/step
# Epoch 374/500
# 23/23 - 0s - loss: 1.7520 - accuracy: 0.8261 - 42ms/epoch - 2ms/step
# Epoch 375/500
# 23/23 - 0s - loss: 1.7506 - accuracy: 0.8261 - 45ms/epoch - 2ms/step
# Epoch 376/500
# 23/23 - 0s - loss: 1.7493 - accuracy: 0.8261 - 54ms/epoch - 2ms/step
# Epoch 377/500
# 23/23 - 0s - loss: 1.7480 - accuracy: 0.8261 - 47ms/epoch - 2ms/step
# Epoch 378/500
# 23/23 - 0s - loss: 1.7467 - accuracy: 0.8261 - 51ms/epoch - 2ms/step
# Epoch 379/500
# 23/23 - 0s - loss: 1.7453 - accuracy: 0.8261 - 54ms/epoch - 2ms/step
# Epoch 380/500
# 23/23 - 0s - loss: 1.7440 - accuracy: 0.8261 - 46ms/epoch - 2ms/step
# Epoch 381/500
# 23/23 - 0s - loss: 1.7427 - accuracy: 0.8261 - 50ms/epoch - 2ms/step
# Epoch 382/500
# 23/23 - 0s - loss: 1.7414 - accuracy: 0.8261 - 49ms/epoch - 2ms/step
# Epoch 383/500
# 23/23 - 0s - loss: 1.7401 - accuracy: 0.8261 - 42ms/epoch - 2ms/step
# Epoch 384/500
# 23/23 - 0s - loss: 1.7388 - accuracy: 0.8261 - 46ms/epoch - 2ms/step
# Epoch 385/500
# 23/23 - 0s - loss: 1.7375 - accuracy: 0.8261 - 45ms/epoch - 2ms/step
# Epoch 386/500
# 23/23 - 0s - loss: 1.7362 - accuracy: 0.8261 - 48ms/epoch - 2ms/step
# Epoch 387/500
# 23/23 - 0s - loss: 1.7349 - accuracy: 0.8261 - 53ms/epoch - 2ms/step
# Epoch 388/500
# 23/23 - 0s - loss: 1.7336 - accuracy: 0.8261 - 47ms/epoch - 2ms/step
# Epoch 389/500
# 23/23 - 0s - loss: 1.7324 - accuracy: 0.8261 - 42ms/epoch - 2ms/step
# Epoch 390/500
# 23/23 - 0s - loss: 1.7311 - accuracy: 0.8261 - 45ms/epoch - 2ms/step
# Epoch 391/500
# 23/23 - 0s - loss: 1.7298 - accuracy: 0.8261 - 45ms/epoch - 2ms/step
# Epoch 392/500
# 23/23 - 0s - loss: 1.7285 - accuracy: 0.8261 - 48ms/epoch - 2ms/step
# Epoch 393/500
# 23/23 - 0s - loss: 1.7273 - accuracy: 0.8261 - 43ms/epoch - 2ms/step
# Epoch 394/500
# 23/23 - 0s - loss: 1.7260 - accuracy: 0.8261 - 43ms/epoch - 2ms/step
# Epoch 395/500
# 23/23 - 0s - loss: 1.7248 - accuracy: 0.8261 - 50ms/epoch - 2ms/step
# Epoch 396/500
# 23/23 - 0s - loss: 1.7235 - accuracy: 0.8261 - 61ms/epoch - 3ms/step
# Epoch 397/500
# 23/23 - 0s - loss: 1.7223 - accuracy: 0.8261 - 43ms/epoch - 2ms/step
# Epoch 398/500
# 23/23 - 0s - loss: 1.7210 - accuracy: 0.8261 - 42ms/epoch - 2ms/step
# Epoch 399/500
# 23/23 - 0s - loss: 1.7198 - accuracy: 0.8261 - 46ms/epoch - 2ms/step
# Epoch 400/500
# 23/23 - 0s - loss: 1.7185 - accuracy: 0.8261 - 44ms/epoch - 2ms/step
# Epoch 401/500
# 23/23 - 0s - loss: 1.7173 - accuracy: 0.8261 - 48ms/epoch - 2ms/step
# Epoch 402/500
# 23/23 - 0s - loss: 1.7161 - accuracy: 0.8261 - 45ms/epoch - 2ms/step
# Epoch 403/500
# 23/23 - 0s - loss: 1.7148 - accuracy: 0.8261 - 47ms/epoch - 2ms/step
# Epoch 404/500
# 23/23 - 0s - loss: 1.7136 - accuracy: 0.8261 - 48ms/epoch - 2ms/step
# Epoch 405/500
# 23/23 - 0s - loss: 1.7124 - accuracy: 0.8261 - 45ms/epoch - 2ms/step
# Epoch 406/500
# 23/23 - 0s - loss: 1.7112 - accuracy: 0.8261 - 45ms/epoch - 2ms/step
# Epoch 407/500
# 23/23 - 0s - loss: 1.7100 - accuracy: 0.8261 - 44ms/epoch - 2ms/step
# Epoch 408/500
# 23/23 - 0s - loss: 1.7088 - accuracy: 0.8261 - 51ms/epoch - 2ms/step
# Epoch 409/500
# 23/23 - 0s - loss: 1.7076 - accuracy: 0.8261 - 43ms/epoch - 2ms/step
# Epoch 410/500
# 23/23 - 0s - loss: 1.7064 - accuracy: 0.8261 - 48ms/epoch - 2ms/step
# Epoch 411/500
# 23/23 - 0s - loss: 1.7052 - accuracy: 0.8261 - 56ms/epoch - 2ms/step
# Epoch 412/500
# 23/23 - 0s - loss: 1.7040 - accuracy: 0.8261 - 60ms/epoch - 3ms/step
# Epoch 413/500
# 23/23 - 0s - loss: 1.7028 - accuracy: 0.8261 - 71ms/epoch - 3ms/step
# Epoch 414/500
# 23/23 - 0s - loss: 1.7016 - accuracy: 0.8261 - 61ms/epoch - 3ms/step
# Epoch 415/500
# 23/23 - 0s - loss: 1.7004 - accuracy: 0.8261 - 73ms/epoch - 3ms/step
# Epoch 416/500
# 23/23 - 0s - loss: 1.6992 - accuracy: 0.8261 - 60ms/epoch - 3ms/step
# Epoch 417/500
# 23/23 - 0s - loss: 1.6980 - accuracy: 0.8261 - 58ms/epoch - 3ms/step
# Epoch 418/500
# 23/23 - 0s - loss: 1.6969 - accuracy: 0.8261 - 60ms/epoch - 3ms/step
# Epoch 419/500
# 23/23 - 0s - loss: 1.6957 - accuracy: 0.8261 - 64ms/epoch - 3ms/step
# Epoch 420/500
# 23/23 - 0s - loss: 1.6945 - accuracy: 0.8261 - 68ms/epoch - 3ms/step
# Epoch 421/500
# 23/23 - 0s - loss: 1.6934 - accuracy: 0.8261 - 60ms/epoch - 3ms/step
# Epoch 422/500
# 23/23 - 0s - loss: 1.6922 - accuracy: 0.8261 - 61ms/epoch - 3ms/step
# Epoch 423/500
# 23/23 - 0s - loss: 1.6911 - accuracy: 0.8261 - 61ms/epoch - 3ms/step
# Epoch 424/500
# 23/23 - 0s - loss: 1.6899 - accuracy: 0.8261 - 73ms/epoch - 3ms/step
# Epoch 425/500
# 23/23 - 0s - loss: 1.6888 - accuracy: 0.8261 - 63ms/epoch - 3ms/step
# Epoch 426/500
# 23/23 - 0s - loss: 1.6876 - accuracy: 0.8261 - 62ms/epoch - 3ms/step
# Epoch 427/500
# 23/23 - 0s - loss: 1.6865 - accuracy: 0.8261 - 60ms/epoch - 3ms/step
# Epoch 428/500
# 23/23 - 0s - loss: 1.6853 - accuracy: 0.8261 - 60ms/epoch - 3ms/step
# Epoch 429/500
# 23/23 - 0s - loss: 1.6842 - accuracy: 0.8261 - 67ms/epoch - 3ms/step
# Epoch 430/500
# 23/23 - 0s - loss: 1.6830 - accuracy: 0.8261 - 71ms/epoch - 3ms/step
# Epoch 431/500
# 23/23 - 0s - loss: 1.6819 - accuracy: 0.8261 - 70ms/epoch - 3ms/step
# Epoch 432/500
# 23/23 - 0s - loss: 1.6808 - accuracy: 0.8261 - 65ms/epoch - 3ms/step
# Epoch 433/500
# 23/23 - 0s - loss: 1.6797 - accuracy: 0.8261 - 67ms/epoch - 3ms/step
# Epoch 434/500
# 23/23 - 0s - loss: 1.6785 - accuracy: 0.8261 - 64ms/epoch - 3ms/step
# Epoch 435/500
# 23/23 - 0s - loss: 1.6774 - accuracy: 0.8261 - 64ms/epoch - 3ms/step
# Epoch 436/500
# 23/23 - 0s - loss: 1.6763 - accuracy: 0.8261 - 63ms/epoch - 3ms/step
# Epoch 437/500
# 23/23 - 0s - loss: 1.6752 - accuracy: 0.8261 - 60ms/epoch - 3ms/step
# Epoch 438/500
# 23/23 - 0s - loss: 1.6741 - accuracy: 0.8261 - 62ms/epoch - 3ms/step
# Epoch 439/500
# 23/23 - 0s - loss: 1.6730 - accuracy: 0.8261 - 62ms/epoch - 3ms/step
# Epoch 440/500
# 23/23 - 0s - loss: 1.6719 - accuracy: 0.8261 - 65ms/epoch - 3ms/step
# Epoch 441/500
# 23/23 - 0s - loss: 1.6708 - accuracy: 0.8261 - 64ms/epoch - 3ms/step
# Epoch 442/500
# 23/23 - 0s - loss: 1.6697 - accuracy: 0.8261 - 62ms/epoch - 3ms/step
# Epoch 443/500
# 23/23 - 0s - loss: 1.6686 - accuracy: 0.8261 - 61ms/epoch - 3ms/step
# Epoch 444/500
# 23/23 - 0s - loss: 1.6675 - accuracy: 0.8261 - 62ms/epoch - 3ms/step
# Epoch 445/500
# 23/23 - 0s - loss: 1.6664 - accuracy: 0.8261 - 68ms/epoch - 3ms/step
# Epoch 446/500
# 23/23 - 0s - loss: 1.6653 - accuracy: 0.8261 - 67ms/epoch - 3ms/step
# Epoch 447/500
# 23/23 - 0s - loss: 1.6642 - accuracy: 0.8261 - 65ms/epoch - 3ms/step
# Epoch 448/500
# 23/23 - 0s - loss: 1.6632 - accuracy: 0.8261 - 62ms/epoch - 3ms/step
# Epoch 449/500
# 23/23 - 0s - loss: 1.6621 - accuracy: 0.8261 - 65ms/epoch - 3ms/step
# Epoch 450/500
# 23/23 - 0s - loss: 1.6610 - accuracy: 0.8261 - 64ms/epoch - 3ms/step
# Epoch 451/500
# 23/23 - 0s - loss: 1.6599 - accuracy: 0.8261 - 64ms/epoch - 3ms/step
# Epoch 452/500
# 23/23 - 0s - loss: 1.6589 - accuracy: 0.8261 - 63ms/epoch - 3ms/step
# Epoch 453/500
# 23/23 - 0s - loss: 1.6578 - accuracy: 0.8261 - 61ms/epoch - 3ms/step
# Epoch 454/500
# 23/23 - 0s - loss: 1.6567 - accuracy: 0.8261 - 68ms/epoch - 3ms/step
# Epoch 455/500
# 23/23 - 0s - loss: 1.6557 - accuracy: 0.8261 - 62ms/epoch - 3ms/step
# Epoch 456/500
# 23/23 - 0s - loss: 1.6546 - accuracy: 0.8696 - 45ms/epoch - 2ms/step
# Epoch 457/500
# 23/23 - 0s - loss: 1.6536 - accuracy: 0.8696 - 47ms/epoch - 2ms/step
# Epoch 458/500
# 23/23 - 0s - loss: 1.6525 - accuracy: 0.8696 - 41ms/epoch - 2ms/step
# Epoch 459/500
# 23/23 - 0s - loss: 1.6514 - accuracy: 0.8696 - 44ms/epoch - 2ms/step
# Epoch 460/500
# 23/23 - 0s - loss: 1.6504 - accuracy: 0.8696 - 45ms/epoch - 2ms/step
# Epoch 461/500
# 23/23 - 0s - loss: 1.6494 - accuracy: 0.8696 - 52ms/epoch - 2ms/step
# Epoch 462/500
# 23/23 - 0s - loss: 1.6483 - accuracy: 0.8696 - 56ms/epoch - 2ms/step
# Epoch 463/500
# 23/23 - 0s - loss: 1.6473 - accuracy: 0.8696 - 48ms/epoch - 2ms/step
# Epoch 464/500
# 23/23 - 0s - loss: 1.6462 - accuracy: 0.8696 - 46ms/epoch - 2ms/step
# Epoch 465/500
# 23/23 - 0s - loss: 1.6452 - accuracy: 0.8696 - 45ms/epoch - 2ms/step
# Epoch 466/500
# 23/23 - 0s - loss: 1.6442 - accuracy: 0.8696 - 47ms/epoch - 2ms/step
# Epoch 467/500
# 23/23 - 0s - loss: 1.6431 - accuracy: 0.8696 - 50ms/epoch - 2ms/step
# Epoch 468/500
# 23/23 - 0s - loss: 1.6421 - accuracy: 0.8696 - 43ms/epoch - 2ms/step
# Epoch 469/500
# 23/23 - 0s - loss: 1.6411 - accuracy: 0.8696 - 47ms/epoch - 2ms/step
# Epoch 470/500
# 23/23 - 0s - loss: 1.6401 - accuracy: 0.8696 - 43ms/epoch - 2ms/step
# Epoch 471/500
# 23/23 - 0s - loss: 1.6390 - accuracy: 0.8696 - 50ms/epoch - 2ms/step
# Epoch 472/500
# 23/23 - 0s - loss: 1.6380 - accuracy: 0.8696 - 43ms/epoch - 2ms/step
# Epoch 473/500
# 23/23 - 0s - loss: 1.6370 - accuracy: 0.8696 - 46ms/epoch - 2ms/step
# Epoch 474/500
# 23/23 - 0s - loss: 1.6360 - accuracy: 0.8696 - 45ms/epoch - 2ms/step
# Epoch 475/500
# 23/23 - 0s - loss: 1.6350 - accuracy: 0.8696 - 44ms/epoch - 2ms/step
# Epoch 476/500
# 23/23 - 0s - loss: 1.6340 - accuracy: 0.8696 - 54ms/epoch - 2ms/step
# Epoch 477/500
# 23/23 - 0s - loss: 1.6330 - accuracy: 0.8696 - 48ms/epoch - 2ms/step
# Epoch 478/500
# 23/23 - 0s - loss: 1.6320 - accuracy: 0.8696 - 45ms/epoch - 2ms/step
# Epoch 479/500
# 23/23 - 0s - loss: 1.6310 - accuracy: 0.8696 - 43ms/epoch - 2ms/step
# Epoch 480/500
# 23/23 - 0s - loss: 1.6300 - accuracy: 0.8696 - 45ms/epoch - 2ms/step
# Epoch 481/500
# 23/23 - 0s - loss: 1.6290 - accuracy: 0.8696 - 53ms/epoch - 2ms/step
# Epoch 482/500
# 23/23 - 0s - loss: 1.6280 - accuracy: 0.8696 - 53ms/epoch - 2ms/step
# Epoch 483/500
# 23/23 - 0s - loss: 1.6270 - accuracy: 0.8696 - 46ms/epoch - 2ms/step
# Epoch 484/500
# 23/23 - 0s - loss: 1.6260 - accuracy: 0.8696 - 44ms/epoch - 2ms/step
# Epoch 485/500
# 23/23 - 0s - loss: 1.6250 - accuracy: 0.8696 - 53ms/epoch - 2ms/step
# Epoch 486/500
# 23/23 - 0s - loss: 1.6240 - accuracy: 0.8696 - 48ms/epoch - 2ms/step
# Epoch 487/500
# 23/23 - 0s - loss: 1.6231 - accuracy: 0.8696 - 49ms/epoch - 2ms/step
# Epoch 488/500
# 23/23 - 0s - loss: 1.6221 - accuracy: 0.8696 - 44ms/epoch - 2ms/step
# Epoch 489/500
# 23/23 - 0s - loss: 1.6211 - accuracy: 0.8696 - 49ms/epoch - 2ms/step
# Epoch 490/500
# 23/23 - 0s - loss: 1.6201 - accuracy: 0.8696 - 53ms/epoch - 2ms/step
# Epoch 491/500
# 23/23 - 0s - loss: 1.6192 - accuracy: 0.8696 - 44ms/epoch - 2ms/step
# Epoch 492/500
# 23/23 - 0s - loss: 1.6182 - accuracy: 0.8696 - 45ms/epoch - 2ms/step
# Epoch 493/500
# 23/23 - 0s - loss: 1.6172 - accuracy: 0.8696 - 51ms/epoch - 2ms/step
# Epoch 494/500
# 23/23 - 0s - loss: 1.6163 - accuracy: 0.8696 - 46ms/epoch - 2ms/step
# Epoch 495/500
# 23/23 - 0s - loss: 1.6153 - accuracy: 0.8696 - 44ms/epoch - 2ms/step
# Epoch 496/500
# 23/23 - 0s - loss: 1.6143 - accuracy: 0.8696 - 46ms/epoch - 2ms/step
# Epoch 497/500
# 23/23 - 0s - loss: 1.6134 - accuracy: 0.8696 - 44ms/epoch - 2ms/step
# Epoch 498/500
# 23/23 - 0s - loss: 1.6124 - accuracy: 0.8696 - 45ms/epoch - 2ms/step
# Epoch 499/500
# 23/23 - 0s - loss: 1.6115 - accuracy: 0.8696 - 52ms/epoch - 2ms/step
# Epoch 500/500
# 23/23 - 0s - loss: 1.6105 - accuracy: 0.8696 - 46ms/epoch - 2ms/step
# Model Accuracy: 86.96%
# ['A', 'B', 'C'] -> D
# ['B', 'C', 'D'] -> E
# ['C', 'D', 'E'] -> F
# ['D', 'E', 'F'] -> G
# ['E', 'F', 'G'] -> H
# ['F', 'G', 'H'] -> I
# ['G', 'H', 'I'] -> J
# ['H', 'I', 'J'] -> K
# ['I', 'J', 'K'] -> L
# ['J', 'K', 'L'] -> M
# ['K', 'L', 'M'] -> N
# ['L', 'M', 'N'] -> O
# ['M', 'N', 'O'] -> P
# ['N', 'O', 'P'] -> Q
# ['O', 'P', 'Q'] -> R
# ['P', 'Q', 'R'] -> S
# ['Q', 'R', 'S'] -> T
# ['R', 'S', 'T'] -> U
# ['S', 'T', 'U'] -> V
# ['T', 'U', 'V'] -> X
# ['U', 'V', 'W'] -> Z
# ['V', 'W', 'X'] -> Z
# ['W', 'X', 'Y'] -> Z
